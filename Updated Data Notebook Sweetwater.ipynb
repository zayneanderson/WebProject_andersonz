# %%
import pandas as pd

filename = '/Users/Zayne/Desktop/CSC3130/WebProject_andersonz/2017-02-23.sweetWater.json'
#filename = '2017-02-23.sweetWater.json'
data = pd.read_json(filename)

# %%
data
# Out:
#                                            Description  \
# 0    6-string Acoustic-electric Travel Guitar with ...
# 1    6-string Acoustic Guitar with Spruce Top, Maho...
# 2    6-string Acoustic Guitar with Tropical Mahogan...
# 3    6-string Acoustic-electric Guitar with Solid S...
# 4    6-string Acoustic-electric Travel Guitar with ...
# 5    6-string Acoustic-electric Guitar with Sitka S...
# 6    6-string Acoustic-electric Guitar with Sapele ...
# 7    6-string Acoustic Guitar with Solid Mahogany T...
# 8    6-string Acoustic Guitar with Sitka Spruce Top...
# 9    Dreadnought Acoustic Guitar with Spruce Top, A...
# 10   6-string Acoustic Guitar with Sitka Spruce Top...
# 11   6-string Acoustic-electric Guitar with Sitka S...
# 12   6-string Acoustic-electric Guitar with Solid S...
# 13   6-string Acoustic Guitar with Sitka Spruce Top...
# 14   6-string Acoustic Guitar with Black Finish and...
# 15   6-string Acoustic Guitar with Mahogany Top and...
# ...

# %%
data.head(295)
# Out:
#                                            Description  \
# 0    6-string Acoustic-electric Travel Guitar with ...
# 1    6-string Acoustic Guitar with Spruce Top, Maho...
# 2    6-string Acoustic Guitar with Tropical Mahogan...
# 3    6-string Acoustic-electric Guitar with Solid S...
# 4    6-string Acoustic-electric Travel Guitar with ...
# 5    6-string Acoustic-electric Guitar with Sitka S...
# 6    6-string Acoustic-electric Guitar with Sapele ...
# 7    6-string Acoustic Guitar with Solid Mahogany T...
# 8    6-string Acoustic Guitar with Sitka Spruce Top...
# 9    Dreadnought Acoustic Guitar with Spruce Top, A...
# 10   6-string Acoustic Guitar with Sitka Spruce Top...
# 11   6-string Acoustic-electric Guitar with Sitka S...
# 12   6-string Acoustic-electric Guitar with Solid S...
# 13   6-string Acoustic Guitar with Sitka Spruce Top...
# 14   6-string Acoustic Guitar with Black Finish and...
# 15   6-string Acoustic Guitar with Mahogany Top and...
# ...
