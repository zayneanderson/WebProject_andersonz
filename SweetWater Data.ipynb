# %%
import pandas as pd

filename = '/Users/Zayne/Desktop/CSC3130/WebProject_andersonz/2017-02-21.sweetWater.json'
#filename = '2017-02-21.sweetWater.json'
data = pd.read_json(filename)

# %%
data
# Out:
#                                           description  \
# 0   6-string Acoustic-electric Travel Guitar with ...
# 1   Acoustic Guitar with Agathis Top, Agathis Back...
# 2   6-string Acoustic Guitar with Tropical Mahogan...
# 3   6-string Acoustic-electric Guitar with Solid S...
# 4   6-string Acoustic-electric Travel Guitar with ...
# 5   6-string Acoustic Guitar with Spruce Top, Maho...
# 6   6-string Acoustic-electric Guitar with Sitka S...
# 7   6-string Acoustic-electric Guitar with Sitka S...
# 8   6-string Acoustic Guitar with Sitka Spruce Top...
# 9   6-string Acoustic Guitar with Solid Mahogany T...
# 10  Dreadnought Acoustic Guitar with Spruce Top, A...
# 11  6-string Acoustic Guitar with Sitka Spruce Top...
# 12  6-string Acoustic-electric Guitar with Solid S...
# 13  6-string Acoustic Guitar with Sitka Spruce Top...
# 14  6-string Acoustic Guitar with Black Finish and...
# 15  6-string Acoustic Guitar with Mahogany Top and...
# ...

# %%
data.description
# Out:
# 0     6-string Acoustic-electric Travel Guitar with ...
# 1     Acoustic Guitar with Agathis Top, Agathis Back...
# 2     6-string Acoustic Guitar with Tropical Mahogan...
# 3     6-string Acoustic-electric Guitar with Solid S...
# 4     6-string Acoustic-electric Travel Guitar with ...
# 5     6-string Acoustic Guitar with Spruce Top, Maho...
# 6     6-string Acoustic-electric Guitar with Sitka S...
# 7     6-string Acoustic-electric Guitar with Sitka S...
# 8     6-string Acoustic Guitar with Sitka Spruce Top...
# 9     6-string Acoustic Guitar with Solid Mahogany T...
# 10    Dreadnought Acoustic Guitar with Spruce Top, A...
# 11    6-string Acoustic Guitar with Sitka Spruce Top...
# 12    6-string Acoustic-electric Guitar with Solid S...
# 13    6-string Acoustic Guitar with Sitka Spruce Top...
# 14    6-string Acoustic Guitar with Black Finish and...
# 15    6-string Acoustic Guitar with Mahogany Top and...
# 16    Acoustic-electric Guitar with Spruce Top, Mapl...
# ...

# %%
i = 0
for style in data.description:
    if('electric') in style:
        print(style)
        print()
        i += 1
print(i)
# Out:
# 6-string Acoustic-electric Travel Guitar with Solid Koa Top, Koa Back and Sides, Sapele Neck, Ebony Fingerboard, and ES2 Electronics - Natural
#
# 6-string Acoustic-electric Guitar with Solid Spruce Top, Mahogany Back and Sides, Mahogany Neck, Rosewood Fingerboard, and Shadow ePerformer Preamp - Faded Cherry Sunburst
#
# 6-string Acoustic-electric Travel Guitar with Sitka Spruce Top, Indian Rosewood Back and Sides, Sapele Neck, Ebony Fingerboard, and ES2 Electronics - Natural
#
# 6-string Acoustic-electric Guitar with Sitka Spruce Top, Sapele Back and Sides, Sapele Neck, Ebony Fretboard, and ES2 Pickup System - Natural
#
# 6-string Acoustic-electric Guitar with Sitka Spruce Top, Sapele Back and Sides, Mahogany Neck, Ebony Fretboard, and ES2 Pickup System - Natural
#
# 6-string Acoustic-electric Guitar with Solid Spruce Top, Maple Back and Sides, Maple Neck, Rosewood Fingerboard, and Fishman Electronics - Violin Burst
#
# ...
